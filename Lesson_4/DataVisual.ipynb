# %%
import pandas as pd

# %%
pd.__version__

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 3E11-2255
#
#  Directory of C:\Users\mdeane\PythonDA\python-class\Lesson_4
#
# 23/05/2020  11:45 AM    <DIR>          .
# 23/05/2020  11:45 AM    <DIR>          ..
# 23/05/2020  09:34 AM    <DIR>          .ipynb_checkpoints
# 23/05/2020  11:45 AM           913,975 DataVisual.ipynb
# 23/05/2020  11:45 AM         3,451,125 lesson_4.ipynb
#                2 File(s)      4,365,100 bytes
#                3 Dir(s)  648,049,172,480 bytes free

# %%
df = pd.read_csv("../datasets/weatherAUS.csv", parse_dates=['Date'])

# %%
df.loc[df['Location'] == 'Sydney'].describe().T
# Out:
#                 count         mean        std    min     25%     50%     75%  \
# MinTemp        3334.0    14.865057   4.553641    4.3    11.0    14.9    18.7
# MaxTemp        3335.0    23.002339   4.494638   11.7    19.6    22.8    26.0
# Rainfall       3331.0     3.330231   9.895172    0.0     0.0     0.0     1.4
# Evaporation    3286.0     5.187432   2.777407    0.0     3.2     4.8     7.0
# Sunshine       3321.0     7.179374   3.810886    0.0     4.3     8.3    10.2
# WindGustSpeed  2301.0    41.761408  13.007523   17.0    31.0    41.0    50.0
# WindSpeed9am   3311.0    15.070674   7.079724    0.0     9.0    15.0    20.0
# WindSpeed3pm   3312.0    19.335447   7.482554    0.0    15.0    19.0    24.0
# Humidity9am    3323.0    68.229010  15.085355   19.0    58.0    69.0    80.0
# Humidity3pm    3324.0    54.699158  16.293530   10.0    44.0    56.0    65.0
# Pressure9am    3317.0  1018.346156   7.021571  986.7  1013.7  1018.6  1023.1
# ...

# %%
from datetime import datetime

# %%
mask = ((df['Location'] == 'Sydney') & 
        (df['Date'] > datetime(2014, 12, 31)) & 
        (df['Date'] < datetime(2016, 1, 1)))

# %%
df.loc[mask].describe().T
# Out:
#                count         mean        std    min     25%     50%       75%  \
# MinTemp        365.0    14.927397   4.693714    5.0    11.0    15.3    18.800
# MaxTemp        365.0    23.146849   4.749068   13.4    19.7    22.6    26.300
# Rainfall       365.0     3.666301  11.462586    0.0     0.0     0.0     1.400
# Evaporation    355.0     5.201127   2.896481    0.0     3.0     5.0     7.000
# Sunshine       362.0     7.049171   3.788284    0.0     4.3     8.0    10.075
# WindGustSpeed  354.0    41.101695  12.774170   19.0    31.0    39.0    48.000
# WindSpeed9am   364.0    14.934066   6.813618    2.0     9.0    15.0    19.000
# WindSpeed3pm   364.0    19.373626   7.704813    2.0    15.0    19.0    24.000
# Humidity9am    365.0    69.731507  15.543424   28.0    58.0    69.0    82.000
# Humidity3pm    365.0    54.978082  16.556748   13.0    44.0    55.0    64.000
# Pressure9am    365.0  1019.651507   7.049326  999.1  1014.8  1019.4  1024.400
# ...

# %%
mask2 =  ((df['Date'] > datetime(2014, 12, 31)) & 
        (df['Date'] < datetime(2016, 1, 1)))

# %%
df.loc[mask2,'Evaporation'].isna().sum()
# Out:
# 8463

# %%
# Let's normalise the columns
df.columns = [col.lower() for col in df.columns]
df.columns


df['year'] = df['date'].dt.year

# %%
df.loc[mask].describe().T
# Out:
#                count         mean        std     min     25%     50%  \
# mintemp        365.0    14.927397   4.693714     5.0    11.0    15.3
# maxtemp        365.0    23.146849   4.749068    13.4    19.7    22.6
# rainfall       365.0     3.666301  11.462586     0.0     0.0     0.0
# evaporation    355.0     5.201127   2.896481     0.0     3.0     5.0
# sunshine       362.0     7.049171   3.788284     0.0     4.3     8.0
# windgustspeed  354.0    41.101695  12.774170    19.0    31.0    39.0
# windspeed9am   364.0    14.934066   6.813618     2.0     9.0    15.0
# windspeed3pm   364.0    19.373626   7.704813     2.0    15.0    19.0
# humidity9am    365.0    69.731507  15.543424    28.0    58.0    69.0
# humidity3pm    365.0    54.978082  16.556748    13.0    44.0    55.0
# pressure9am    365.0  1019.651507   7.049326   999.1  1014.8  1019.4
# pressure3pm    365.0  1017.430411   6.994738   997.2  1012.8  1017.5
# cloud9am       364.0     4.285714   2.712224     0.0     1.0     5.0
# ...

# %%
#groupby to count nan for evaporation by year

# %%
g = df.groupby('year')
g.count().rsub(g.size(), axis=0)
# Out:
#       date  location  mintemp  maxtemp  rainfall  evaporation  sunshine  \
# year
# 2007     0         0        0        0         0            0         0
# 2008     0         0        9        4        17          325       318
# 2009     0         0      117       56        81         5591      6061
# 2010     0         0      124       55       228         5602      5894
# 2011     0         0       45       14       143         5625      5895
# 2012     0         0       40       18       150         5814      6287
# 2013     0         0       48       24       162         6251      7409
# 2014     0         0       51       27       219         7902      8832
# 2015     0         0       43       31       142         8463      9165
# 2016     0         0       76       64       167         9626     11705
# 2017     0         0       84       29        97         5644      6250
#
#       windgustdir  windgustspeed  winddir9am  ...  humidity3pm  pressure9am  \
# ...
